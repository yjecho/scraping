# %%
pip install pytrends
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\whgus\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import pytrends
from pytrends.request import TrendReq
import datetime
import csv

# %%
kw_list = []

# %%
movie2 = pd.read_csv('final3.csv')

# %%
movie2.columns
# Out:
# Index(['Unnamed: 0', 'title', 'directors', 'actors', 'plots', 'runtime',
#        'genre', 'keywords', '개봉일', '국적', 'screenCnt', 'salesAcc', 'audiAcc',
#        '등급', '개봉일2'],
#       dtype='object')

# %%
date1 = movie2['개봉일']

# %%
date2 = movie2['개봉일2'] # 개봉 1달 전 일자

# %%
key = movie2['title']

# %%
key.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6392 entries, 0 to 6391
# Series name: title
# Non-Null Count  Dtype
# --------------  -----
# 6392 non-null   object
# dtypes: object(1)
# memory usage: 50.1+ KB

# %%
i = 0

# %%
for i in range(6000,6393):
    kw_list = key[i:i+1]
    pytrends = TrendReq(hl = "ko", tz = 360)
    pytrends.build_payload(kw_list, cat=0, timeframe= "{0} {1}".format(date1[i], date2[i]), geo='', gprop='')
    getdatainfo = pytrends.interest_over_time()
    print(getdatainfo)
    getdatainfo.to_csv("trend%d.csv" % i, encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
#       2 kw_list = key[i:i+1]
#       3 pytrends = TrendReq(hl = "ko", tz = 360)
# ----> 4 pytrends.build_payload(kw_list, cat=0, timeframe= "{0} {1}".format(date1[i], date2[i]), geo='', gprop='')
#       5 getdatainfo = pytrends.interest_over_time()
#       6 print(getdatainfo)
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/pytrends/request.py:183, in TrendReq.build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     181 self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     182 # get tokens
# --> 183 self._tokens()
#     184 return
#
# File ~/miniforge3/envs/tf25/lib/python3.8/site-packages/pytrends/request.py:189, in TrendReq._tokens(self)
# ...
