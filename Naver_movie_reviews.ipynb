# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=154282&type=after&onlyActualPointYn=N&onlySpoilerPointYn=N&order=sympathyScore&page=%7b%7d'
html = urlopen(url)
soup = BeautifulSoup(html,'html.parser')

# %%
# %%time
rating_list = []
review_list = []

for page in range(1,6000):
    try:
        url = f'https://movie.naver.com/movie/bi/mi/pointWriteFormList.naver?code=154282&type=after&onlyActualPointYn=N&onlySpoilerPointYn=N&order=sympathyScore&page={page}'
        html = urlopen(url)
        soup = BeautifulSoup(html,'html.parser')
        for i in range(10):
            rating = soup.select('div > em')
            rating = rating[i].get_text()
            rating_list.append(rating)
            
            review = soup.find('span',{'id':f'_filtered_ment_{i}'})            
            review = review.get_text().strip()
            review_list.append(review)
    except:
        pass

print(len(rating_list))
print(rating_list)
print(len(review_list))
print(review_list)
# Out:
# 7895
# ['10', '10', '10', '10', '10', '10', '9', '8', '9', '7', '4', '2', '7', '8', '10', '4', '8', '9', '9', '10', '7', '10', '10', '10', '10', '10', '10', '7', '10', '1', '10', '10', '5', '7', '10', '9', '10', '10', '6', '7', '3', '10', '10', '10', '10', '3', '10', '6', '6', '7', '8', '10', '10', '10', '8', '9', '10', '8', '10', '7', '1', '8', '5', '2', '7', '10', '9', '7', '10', '9', '3', '7', '10', '10', '10', '10', '6', '10', '8', '7', '10', '9', '10', '10', '10', '8', '10', '7', '7', '7', '6', '8', '10', '10', '8', '10', '10', '10', '8', '10', '10', '10', '9', '4', '7', '8', '10', '8', '8', '10', '10', '6', '10', '9', '10', '8', '10', '10', '9', '6', '4', '10', '9', '7', '7', '10', '8', '6', '9', '10', '4', '1', '7', '6', '2', '6', '6', '8', '10', '7', '10', '1', '9', '8', '10', '8', '8', '10', '10', '6', '9', '10', '8', '7', '5', '10', '10', '8', '6', '7', '1', '10', '9', '8', '6', '6', '8', '8', '10', '10', '8', '7', '7', '10', '8', '10', '6', '10', '6', '9', '4', '7', '1', '1', '4', '8', '9', '10', '8', '8', '10', '10', '8', '8', '8', '8', '7', '9', '8', '10', '5', '10', '8', '6', '8', '9', '9', '10', '5', '6', '8', '9', '2', '2', '1', '10', '9', '8', '7', '9', '10', '10', '7', '10', '10', '8', '8', '7', '8', '8', '10', '9', '7', '2', '10', '8', '9', '10', '10', '8', '8', '8', '8', '10', '10', '10', '10', '6', '10', '9', '8', '10', '4', '7', '7', '2', '2', '4', '1', '2', '1', '1', '1', '1', '4', '10', '8', '8', '8', '9', '1', '8', '4', '8', '6', '10', '8', '1', '9', '8', '6', '8', '9', '9', '9', '8', '8', '8', '6', '10', '6', '4', '10', '7', '8', '10', '10', '8', '7', '8', '7', '10', '8', '8', '8', '10', '10', '9', '7', '6', '10', '10', '10', '9', '10', '10', '10', '7', '6', '2', '6', '2', '2', '5', '1', '6', '1', '1', '1', '5', '9', '8', '8', '2', '8', '7', '9', '2', '2', '1', '1', '4', '10', '8', '10', '7', '10', '1', '10', '8', '1', '2', '2', '9', '10', '10', '10', '8', '8', '9', '7', '10', '8', '8', '8', '10', '8', '8',
틴슨씨 돈 많이 버시고 행복하시고 배트맨 또 찍어주십시오 진짜 캐스팅 개잘했다 개잘어울리고 목소리도 개쩜', '중간의 자동차 액션씬이 좋았습니다. 러닝타임이 짧았다면 좋았을거같아요. 전체적인 어두운분위기는 마음에 들었습니다.', '영화의 메인 빌런인 리들러 보다 중간 인물들의 존재감이 보다 강렬하다는 것. 펭귄 역의 콜린 파렐 씨의 연기는 압도적이며, 팔코네 역의 존 터투로 씨는 태곳적 여유로움으로 깊은 인상을 남기고 다음 편을 기대하게 만든...', 'MCU나 기존 DCEU와는 다른 근본 DC 스타일의 배트맨', '연출,영상미는 좋았어요 그러나 시나리오랑 영화랑 따로노는거 같은 느낌이들어 영화에 깊히 빠져들수없었고 그렇게 큰 감동역시 없었어요 무엇보다 배트맨특유의 다크함을 깨버리는 키스신,쌍팔년도 영화보는줄알았어요', '재미없는 교수가 쉬지않고 수업을 하는 느낌.긴장감을 조성하는 효과음과 굼뜬 움직임들이 끊임없이 나와 나중에는 화가 치밀 정도', '놀란의 배트맨 시리즈 재밌게 봤고 조커도 너무 재밌게 본 사람으로써 로버트 패틴슨의 새로운 브루스 웨인이 dc의 부흥기를 일으킬 수 있을까 너무 기대하면서 개봉당일날 시청했습니다. 결론부터 말하면 쓰레기 영화 입니다...', '소개팅에 나갔는데 엄청 잘생긴 남자가 나와서 설렜어요. 근데 말을 잘해요. 그래서 들어보려했는데.. 이야기가 기네요.. 그리고 내용이 재미가 없어요.... 엄청 어두운 이야기를 해주는데 자꾸 딴생각을 하게 되서 미안...', '배트맨 골수팬 : 와 세 시간동안 감탄했다,  일반인 : 와 세 시간동안 졸았다', '역시 배트맨은 어두워야 한다.', '배트맨은 도대체 뭘 하겠다고 싸돌아다니는 건가? 리들러는 도대체 뭐 때문에 소동을 벌이는가? 감독은 도대체 무슨 생각으로 이런 엉성한 각본을 3시간 동안 찍어대는가?', '뭔가 싸이월드에 나는 오늘도 눈물을 흘린다 글쓸거같는 배트맨이다 캣우먼은 그냥 나오지 않는게 낫지 않앗을까? 우크라이나 화이팅', '가장 미숙했지만 가장 두려웠던 배트맨. 가장 나약했기에 가장 인간적이었던 배트맨.', '이 영화가 끝나고 주차장에서 차 타고 집 올때 풀악셀 밟는 나를 발견했다...', '재밌네요. 아캄나이트 하는 줄 ㅋㅋㅋ', '배트맨의 연출과 Ost는 인상적. 3시간의 러닝타임을 감수할 만큼의 전개 였는지는 의문.', '카체이스씬과 기관총 격투 장면은 그야말로 압권', '내가 원하던 배트맨 이거잖아,,,', '개봉 전 알려진대로 미성숙한 배트맨이다. 그러나 어둠속에서 그림자 그 자체로 존재하던 배트맨이 자신의 의미를 깨달으며 빛과 함께 등장하고, 마지막에는 본인이 빛이 되어 시민들을 인도한다. 다른 관람객분의 말씀대로 화...', '자타공인 세계 최고의 히어로이자 다른 모든 히어로물과 철저히 구분되는 범죄 느와르 배트맨! 그 명성에 걸맞도록 놀란에 이어 또다른 전설의 3부작이 될 수 있기를 염원합니다!', '와.. 진심 쩐다.. 압도적인 몰입감과 고뇌하는배트맨', '걍 보세요 이건 히어로 장르를 넘어섰어요', '다크나이트 같은거 생각하면 좀 많이 실망스러울 수 있음근데 전체적으로 나쁘지는 않은데 뭐라고 해야하지? 미묘함별점 6점은 너무 적은거 같고 8점은 너무 많은거 같은 그런 영화임', '호아킨의 조커를 배트맨에서 볼 수 있었으면 좋겠다 간절히..', '그래. 나도 이것저것 감안하고 봤다. 근데 이건 아니지', '액션 기대 많이했는데 너무 잘 뽑아서 속이 시원했음 ost도 취향이었음 아맥에서 무조건 한 번 더 봐야됨 아맥 있으면 무조건 아맥으로 ㄱ ㄱ', '초보 배트맨의 성장기색다른 히어로물', '히어로 영화는 히어로뿐만 아니라 빌런의 매력도 중요하다. 리들러는 라스 알 굴, 조커, 베인 등 앞선 배트맨 영화에 나왔던 악당들에 비해 빌런으로서의 매력이 한참 뒤떨어진다. 자꾸 유치한 수수께끼를 뒤쫓게 시켜서 러...', '이쯤되면 끝인 줄 알았는데 이렇게나 끝이 안나는 것은 <?>', '점수가 너무 낮은것같아서 10점 줬지만 실제 평점은 8.8점 정도주고 싶음 영상미 ost 연기 연출 완벽함 스토리 라인이 3편만들 초석이라고 생각하면 양호함. 영화는 배트맨이 현실에 존재했으면 어땠을까라고 했으면 어...', '만족스러운 새 배트맨시리즈 첫 영화어두운 분위기를 잘 표현했고 영상미가 좋음', '어둠이 묵직하게 깔린 고담에서 인간 브루스 웨인과 히어로 배트맨을 만나다.', '개인적으로 지루하지않았습니다. 여태 봐왔던 배트맨과 달리 장르가 좀 바뀌였을뿐 .... 그동안 배트맨은 악당이 빛났으면 이번 배트맨은 정말말그대로 주인공을 부곽되게 잘 표현한 영화인것같습니다 ... 특히나 로버트 패...', '크리찬 베일 형님이 보고싶더라', '이렇게까지 세시간짜리 영화를 만들 필요가 있나..? 재밌는 세시간도 아니고 흡입력도 없고 머.. 기대 안 했는데 안 하길 잘했고 세시간 내내 시커매서 눈 침침함', '복수에서 희망으로 이행되는 멋진 메시지. 그러나 재미는 산으로, 관객들은 영화평으로 복수하기 시작했다.', '상당히 어둡지만 그게 또 고담시와는 찰떡궁합... 마치 애거사 크리스티의 추리물을 떠올리는 장면도 종종 있는데다가 간간히 들려오는 베토벤의 클래식은 영화를 더욱 풍성하게 만들어주네요!', '복수자에서 영웅으로...', '배트맨 특유의 다크한 분위기를 잘 살림배우가 찰떡', '로버트팬틴슨 벤애플렉의 배트맨을 잘이어주기를', '슈퍼히로우보단 실무탐정에 가까운 배트맨.. 영상미는 훌륭한데 재미는 없다 러닝타임도 너무 길고.. 근데 후기댓글들을 보다보니 그게 DC(detective comics)의 초기 원류에 가깝다는 사람들도 있고... 그런...', '도대체 배트맨 아빠 몇 번 죽이는 거냐', '러닝타임이 너무 길었습니다.또한 차량추격씬 말고는 지루했습니다.', '빌런이 너무 찌질하다...어디선가 본거같은 익숙한...', '복수에서 희망으로.', '배트맨은 앞으로 단독영화만 찍자 제발', '이만하면 새로운 배트맨 시리즈의 성공적인 안착. 다름편 기대된다!', '로버트 패틴슨 새로운 모습에 놀람,, 테넷에서도 이런 모습이 있나 놀랐었는데 이번에 진짜 배트맨으로 다시 봄', '일단 분위기는 그동안 배트맨 영화중 제일 어둡습니다 패틴슨의 배트맨도 생각보다 훌륭하네요 러닝타임이 길긴 한데 개인적으론 지루하지 않았습니다 오히려 일부 갈등구조가 너무 빨리 해소되는게 아쉽더라구요 ost도 너무 좋...', '중간 자동차액션씬까지는 최고. 마무리는  좀 아쉬움', '역대 배트맨 영화 중 가장 배트맨 자체에 집중한 영화. 고담시에 갔다 온 것 같은 연출.', '엄청 재밌게 봤음 진짜 시간 가는 줄 모르고 푹 빠져서 본듯 연휴 최고의 선택', '액션 블록버스터를 기대하는자, 새롭게 눈을 뜨거나 휴대폰으로 시간을 확인하거나.', '역대 배트맨 영화중 배트맨 캐릭터성을 가장 잘뽑은영화', "크리스토퍼 놀란의 '배트맨' 시리즈는 절대 넘을 순 없다는걸 깨닫게 해준 영화...", '너무 지루하다. 차라리 폴 다노 한명에게만 집중했으면 어땠을까.', 'DC는 이렇게 쭉 독자노선으로 갔으면 좋겠다. 전개는 느리고 다소 반복적으로 느껴지지만 시각적으로 굉장히 잘 만들었다.', '너무 길고 지루함', '지루해요 아오 아오 아오', '상영시간이 긴 영화를 좋아하는 편임에도 불구하고 이번 더 베트맨은 굳이 이렇게 길게 늘어뜨려 연출할 필요가 없다고 느낄만한 장면이 많았다. 그 점이 가장 큰 단점이었다. 반면 가장 큰 장점은 딥 다크한 분위기를 시종...', '집에서 봤으면 내 얼굴밖에 안보일듯...', '여기서 별절 낮게 다는 사람은 취향에 안맞는 것 뿐입니다 ...
# CPU times: user 40.9 s, sys: 1.27 s, total: 42.2 s
# Wall time: 2min

# %%
df = pd.DataFrame({"ratings": rating_list, "reviews": review_list})
df = df.drop_duplicates()
df
# Out:
#      ratings                                            reviews
# 0         10  원래 dc가 detective comics의 준말임. 이거에 가장 부합하는 영화인 ...
# 1         10  MCU나 DCEU 같은 분위기를 기대하는 사람이면 그냥 가지마라. 그런 영화 아니니...
# 2         10  전작 배트맨 영화들과 다른 장르 느낌 화려함 느와르 한편 본거 같음 난 다크나이트 ...
# 3         10                             지루..할 수가 있나..?또 보고 싶은데
# 4         10                                       로버트 패틴슨 뜬다뜬다
# ...      ...                                                ...
# 5810       6                              나는 복수다. = 어벤져스에 끼고싶다.
# 5811       2           잡아 쳐 죽이지 배트맨이 무슨 명탐정 코난이냐? 계속 수수께끼만 풀고있네
# 5812       1  진짜 너무너무너무너무너무나 지루하다세 시간에 걸친 졸음과의 대사투!!완전히 잠들지 ...
# 5813       1  기생오래비 같은애가 배트맨이라니...개인적으론 불호....크리스챤베일, 벤애플랙같은...
# 5814       2  마블 매니아~방금 롯데시네마4D보다 나옴3시간 런닝타임~~개지루함~그나마4D로 보다...
#
# [5547 rows x 2 columns]
